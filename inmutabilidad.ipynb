// %% [markdown]
// PILARES DE LA PROGRAMACIÓN FUNCIONAL CON SCALA

// %% [markdown]
// INMUTABILIDAD

// %% [markdown]
// -Todas las variables son creadas como campos val
//
// -Solo se utilizan clases de colecciones inmutables, como List, Vector y las clases inmutables Map y Set.

// %%
val a = List("jane", "jon", "mary", "joe")
val b = a.filter(_.startsWith("j"))
         .map(_.capitalize)
// Out:
// a: List[String] = List("jane", "jon", "mary", "joe")
// b: List[String] = List("Jane", "Jon", "Joe")

// %%
case class Person(firstName: String, lastName: String)

val reginald = Person("Reginald", "Dwight")
val elton = reginald.copy(
  firstName = "Elton",   // update the first name
  lastName = "John"      // update the last name
)
// Out:
// defined class Person
// reginald: Person = Person(firstName = "Reginald", lastName = "Dwight")
// elton: Person = Person(firstName = "Elton", lastName = "John")

// %% [markdown]
// a NO se puede modificar

// %%
val a = List("jane", "jon", "mary", "joe")
val a = List("juana", "sergio")
// Out:
// cell5.sc:2: a is already defined as value a
// val a = List("juana", "sergio")
//     ^
// Compilation Failed
