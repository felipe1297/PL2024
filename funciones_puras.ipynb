// %% [markdown]
// FUNCIONES PURAS
// Ejemplo de función pura que calcula la suma de una lista de enteros

// %%
def sum(xs: List[Int]): Int = xs match {
  case Nil => 0
  case head :: tail => head + sum(tail)
}
// Out:
// defined function sum
